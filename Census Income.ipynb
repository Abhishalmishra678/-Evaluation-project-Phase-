# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
DATA=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')

# %%
df=DATA

# %%
df.head(10)
# Out:
#    Age          Workclass  Fnlwgt      Education  Education_num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            Marital_status          Occupation    Relationship    Race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.tail(10)
# Out:
#        Age      Workclass  Fnlwgt      Education  Education_num  \
# 32550   32        Private   34066           10th              6
# 32551   43        Private   84661      Assoc-voc             11
# 32552   32        Private  116138        Masters             14
# 32553   53        Private  321865        Masters             14
# 32554   22        Private  310152   Some-college             10
# 32555   27        Private  257302     Assoc-acdm             12
# 32556   40        Private  154374        HS-grad              9
# 32557   58        Private  151910        HS-grad              9
# 32558   22        Private  201490        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#             Marital_status          Occupation    Relationship  \
# 32550   Married-civ-spouse   Handlers-cleaners         Husband
# 32551   Married-civ-spouse               Sales         Husband
# 32552        Never-married        Tech-support   Not-in-family
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### the data set contain 32560 rows and 15 columns
# ### 6 int data type and 9   object data type in wich Income column is our dependent variable(lebal)
# ### wich is object type so it is a classification problem
# ### we find no null value in data set .

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
sns.heatmap(df.isnull(),color='red')
# Out:
# <Axes: >

# %% [markdown]
# ### we do not find any null value present

# %%
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
df.nunique().plot(kind='bar')
# Out:
# <Axes: >

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('/n'*45                                 )
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
#  HS-grad         10501
#  Some-college     7291
# ...

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Age ,Fnlwgt columns has little high mean value then median(50%).
# ### Capital_gain ,Capital_loss	 ,Hours_per_week has very high mean value then median(50%) coz there median is 0 ,
# ### except Fnlwgt all columns has very high max value then there 75% DATA

# %%
df.skew()
# Out:
# Age                0.558738
# Fnlwgt             1.446972
# Education_num     -0.311630
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# dtype: float64

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Income',data=df)
# Out:
# <Axes: xlabel='Income', ylabel='count'>

# %% [markdown]
# ### class imbalence is present in the target variable

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Workclass',data=df)
# Out:
# <Axes: xlabel='Workclass', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Education',data=df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Marital_status',data=df)
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Occupation',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Relationship',data=df)
# Out:
# <Axes: xlabel='Relationship', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Race',data=df)
# Out:
# <Axes: xlabel='Race', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Sex',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Native_country',data=df)
# Out:
# <Axes: xlabel='Native_country', ylabel='count'>

# %%
sns.scatterplot(x='Age',y='Fnlwgt',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Fnlwgt'>

# %%
sns.scatterplot(x='Age',y='Education',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Education'>

# %%
sns.scatterplot(x='Age',y='Workclass',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Workclass'>

# %%
sns.scatterplot(x='Age',y='Marital_status',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Marital_status'>

# %%
sns.scatterplot(x='Age',y='Occupation',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Occupation'>

# %%
sns.scatterplot(x='Age',y='Race',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Race'>

# %%
sns.scatterplot(x='Age',y='Sex',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sns.scatterplot(x='Age',y='Capital_gain',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Capital_gain'>

# %%
sns.scatterplot(x='Age',y='Capital_loss',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Capital_loss'>

# %%
sns.scatterplot(x='Age',y='Hours_per_week',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Hours_per_week'>

# %%
sns.scatterplot(x='Age',y='Native_country',hue='Income',data=df,palette='bright')
# Out:
# <Axes: xlabel='Age', ylabel='Native_country'>

# %%
sns.scatterplot(x='Education',y='Income',hue='Sex',data=df,palette='bright')
# Out:
# <Axes: xlabel='Education', ylabel='Income'>

# %%
sns.scatterplot(x='Occupation',y='Income',hue='Sex',data=df,palette='bright')
# Out:
# <Axes: xlabel='Occupation', ylabel='Income'>

# %%
sns.pairplot(df)

# %%
cont_features=[col for col in df.columns if df[col].dtypes!='object']
cont_features
# Out:
# ['Age',
#  'Fnlwgt',
#  'Education_num',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week']

# %%
dfplot=df[{'Age',
 'Fnlwgt',
 'Education_num',
 'Capital_gain',
 'Capital_loss',
 'Hours_per_week'}]

# %%
dfplot
# Out:
#        Hours_per_week  Education_num  Fnlwgt  Capital_loss  Age  Capital_gain
# 0                  13             13   83311             0   50             0
# 1                  40              9  215646             0   38             0
# 2                  40              7  234721             0   53             0
# 3                  40             13  338409             0   28             0
# 4                  40             14  284582             0   37             0
# ...               ...            ...     ...           ...  ...           ...
# 32555              38             12  257302             0   27             0
# 32556              40              9  154374             0   40             0
# 32557              40              9  151910             0   58             0
# 32558              20              9  201490             0   22             0
# 32559              40              9  287927             0   52         15024
#
# [32560 rows x 6 columns]

# %% [markdown]
# ### lets chek the outliersin box plot¶

# %%
plt.figure(figsize=(20,25))
value=1
for col in dfplot:
    if value <=6:
        g=plt.subplot(3,2,value)
        sns.boxplot(dfplot[col],palette="Set2_r")
        plt.xlabel(col,fontsize=14)
        plt.yticks(rotation=0,fontsize=14)
    value+=1
plt.tight_layout()

# %%
from scipy import stats
from scipy.stats import zscore

# %%
z_scor=np.abs(zscore(dfplot))

# %%
np.where(z_scor>3)
# Out:
# (array([    9,    22,    27, ..., 32524, 32524, 32530], dtype=int64),
#  array([0, 3, 0, ..., 0, 4, 0], dtype=int64))

# %%
dfplot.iloc[32524]
# Out:
# Hours_per_week         1
# Education_num         11
# Fnlwgt            120478
# Capital_loss           0
# Age                   81
# Capital_gain           0
# Name: 32524, dtype: int64

# %%
plt.figure(figsize=(20,30))
plot_v=1
for col in dfplot:
    if plot_v <=6:
        p=plt.subplot(3,2,plot_v)
        sns.distplot(dfplot[col],color='red')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout()

# %%
dfplot.skew()
# Out:
# Hours_per_week     0.227636
# Education_num     -0.311630
# Fnlwgt             1.446972
# Capital_loss       4.594549
# Age                0.558738
# Capital_gain      11.953690
# dtype: float64

# %%
df['Capital_gain']=np.cbrt(df['Capital_gain'])    # removing skewness with cube root(cbrt) methode
df['Capital_loss']=np.cbrt(df['Capital_loss'])
df['Fnlwgt']=np.cbrt(df['Fnlwgt'])

# %%
dfplot.skew()
# Out:
# Hours_per_week     0.227636
# Education_num     -0.311630
# Fnlwgt             1.446972
# Capital_loss       4.594549
# Age                0.558738
# Capital_gain      11.953690
# dtype: float64

# %% [markdown]
# ### let chek if data has any multicolinearty issue.¶

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.068166       0.036527      0.124537      0.052890
# Fnlwgt         -0.068166  1.000000      -0.040712     -0.000755     -0.006159
# Education_num   0.036527 -0.040712       1.000000      0.148259      0.078084
# Capital_gain    0.124537 -0.000755       0.148259      1.000000     -0.061453
# Capital_loss    0.052890 -0.006159       0.078084     -0.061453      1.000000
# Hours_per_week  0.068756 -0.022684       0.148127      0.095142      0.052264
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.022684
# Education_num         0.148127
# Capital_gain          0.095142
# Capital_loss          0.052264
# Hours_per_week        1.000000

# %%
cor=df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(cor,linewidths=0.1,fmt='.1g',linecolor='black',annot= True,cmap='Blues_r') # ploting heatmap of corr method.
# Out:
# <Axes: >

# %% [markdown]
# ### capital_loss is negetvly coreelated with capital_gain
# ### anf fnlwgt is negetvly correlated with age
# ### the correlation is not high in any of columns

# %% [markdown]
# # now lets encode the object type columns.¶

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()                                  # encoding withe the lebal encoder.

# %%
df['Workclass'] = label_encoder.fit_transform(df['Workclass'])
df['Education'] = label_encoder.fit_transform(df['Education'])
df['Marital_status'] = label_encoder.fit_transform(df['Marital_status'])
df['Occupation'] = label_encoder.fit_transform(df['Occupation'])
df['Relationship'] = label_encoder.fit_transform(df['Relationship'])
df['Race'] = label_encoder.fit_transform(df['Race'])
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['Native_country'] = label_encoder.fit_transform(df['Native_country'])
df['Income'] = label_encoder.fit_transform(df['Income'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  int32
#  2   Fnlwgt          32560 non-null  float64
#  3   Education       32560 non-null  int32
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  int32
#  6   Occupation      32560 non-null  int32
#  7   Relationship    32560 non-null  int32
#  8   Race            32560 non-null  int32
#  9   Sex             32560 non-null  int32
#  10  Capital_gain    32560 non-null  float64
#  11  Capital_loss    32560 non-null  float64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  int32
#  14  Income          32560 non-null  int32
# dtypes: float64(3), int32(9), int64(3)
# memory usage: 2.6 MB

# %% [markdown]
# ### now lets split the data

# %%
DFX=df.drop('Income', axis=1)
DFY=df['Income']

# %% [markdown]
# ### NOW LETS REMOVE CLASSIMBALENCE FROM THE TARGET VARIABLE

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
DFX,DFY=sm.fit_resample(DFX,DFY)

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=DFY)
# Out:
# <Axes: xlabel='Income', ylabel='count'>

# %%
print('shape of DFY',DFY.shape)
print('shape of DFX',DFX.shape)
# Out:
# shape of DFY (49438,)
# shape of DFX (49438, 14)

# %% [markdown]
# ### now lets scal the all independent variables.¶

# %%
from sklearn.preprocessing import StandardScaler
scal=StandardScaler()

# %%
DFX=pd.DataFrame(scal.fit_transform(DFX),columns=DFX.columns)

# %%
DFX.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  4.943800e+04  4.943800e+04  4.943800e+04  4.943800e+04   4.943800e+04
# mean   3.650590e-17 -1.113861e-16  2.755908e-16  3.808686e-17   1.305014e-16
# std    1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00   1.000010e+00
# min   -1.824942e+00 -2.823439e+00 -3.050970e+00 -2.990523e+00  -3.800318e+00
# 25%   -7.316378e-01  1.188509e-01 -5.899867e-01 -4.052394e-01  -6.098933e-01
# 50%   -2.879959e-02  1.188509e-01  7.233851e-02  1.692681e-01  -2.110902e-01
# 75%    6.740386e-01  1.188509e-01  5.837465e-01  4.565219e-01   9.853190e-01
# max    3.875857e+00  3.061141e+00  5.524323e+00  1.318283e+00   2.181728e+00
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    4.943800e+04  4.943800e+04  4.943800e+04  4.943800e+04  4.943800e+04
# mean     7.876075e-17 -4.397955e-17  4.254231e-17 -1.299265e-16 -1.095177e-16
# ...

# %% [markdown]
# ### lets import all the libreries for models¶

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### first lets get a best rendom stete value¶

# %%
MAXXACU=0
MAXRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(DFX,DFY,test_size=0.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX accuracy is',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX accuracy is 0.8586839266450917 BEST rendom state is 179

# %%
x_train,x_test,y_train,y_test=train_test_split(DFX,DFY,test_size=0.30,random_state=MAXRS)

# %%
def evaluation(model, prediction, x_train, y_train, x_test, y_test):
    print(accuracy_score(y_test,prediction))
    print(confusion_matrix(y_test,prediction))
    print(classification_report(y_test,prediction))   # defing the all evaluation method to one

# %% [markdown]
# ### making all modal as a singal modal¶

# %%
models = {
    'LogisticRegression'         : LogisticRegression(),
    'DecisionTreeClassifier'     : DecisionTreeClassifier(),
    'RandomForestClassifier'     : RandomForestClassifier(),
    'SVC'                        : SVC(),
    'KNeighborsClassifier'       : KNeighborsClassifier(),
    'GaussianNB'                 : GaussianNB(),
    'GradientBoostingClassifier' : GradientBoostingClassifier(),
    'MLPClassifier'              :MLPClassifier(),
    'BaggingClassifier'          :BaggingClassifier(),
    'AdaBoostClassifier'         :AdaBoostClassifier()
}

# %% [markdown]
# ### now lets train all modal at once,

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    prediction1 = model.predict(x_test)
    print('Model: {}'.format(model_name))
    print(evaluation(model, prediction1, x_train, y_train, x_test, y_test))
    print('##########################################################################################')
# Out:
# Model: LogisticRegression
# 0.7624730312837109
# [[5607 1831]
#  [1692 5702]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      7438
#            1       0.76      0.77      0.76      7394
#
#     accuracy                           0.76     14832
#    macro avg       0.76      0.76      0.76     14832
# weighted avg       0.76      0.76      0.76     14832
#
# None
# ##########################################################################################
# Model: DecisionTreeClassifier
# 0.8458063646170443
# [[6221 1217]
#  [1070 6324]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      7438
#            1       0.84      0.86      0.85      7394
#
#     accuracy                           0.85     14832
#    macro avg       0.85      0.85      0.85     14832
# weighted avg       0.85      0.85      0.85     14832
#
# None
# ...

# %% [markdown]
# ## ALL MODEL SCORE:
# ## 'LogisticRegression'         :0.7624730312837109
# ##    'DecisionTreeClassifier'     :0.8458063646170443
# ##   'RandomForestClassifier'     :0.892259978425027
# ##    'SVC'                        :0.8404126213592233
# ##    'KNeighborsClassifier'       :0.8397384034519957
# ##    'GaussianNB'                 : 0.7864751887810141
# ##    'GradientBoostingClassifier' :0.8566612729234089
# ##   'MLPClassifier'              :0.847829018338727
# ##    BaggingClassifier            :0.8705501618122977
# ##    AdaBoostClassifier           :0.8433791801510249

# %% [markdown]
# ### lets cross validate all models with cross_val_score method

# %%
for model_name, model in models.items():
    score=cross_val_score(model,DFX,DFY,cv=5)
    print('Model: {}'.format(model_name))
    print(score)
    print(model.score(x_test, y_test))
    print(score.mean())
    print("                                                                                  ")
    print('deffrence between accuracy_score and cross val_score',(model.score(x_test, y_test)) -(score.mean()))
    print("                                                                                  ")
# Out:
# Model: LogisticRegression
# [0.75596683 0.76537217 0.76668689 0.76565187 0.76686558]
# 0.7624730312837109
# 0.7641086674240929
#
# deffrence between accuracy_score and cross val_score -0.0016356361403819797
#
# Model: DecisionTreeClassifier
# [0.80390372 0.82635518 0.8598301  0.85344392 0.85000506]
# 0.8458063646170443
# 0.8387075940326335
#
# deffrence between accuracy_score and cross val_score 0.007098770584410774
#
# Model: RandomForestClassifier
# [0.84607605 0.86953883 0.90968851 0.91109538 0.90836452]
# 0.892259978425027
# 0.8889526589784958
#
# deffrence between accuracy_score and cross val_score 0.003307319446531176
#
# Model: SVC
# [0.80936489 0.82443366 0.8490089  0.84858906 0.85536563]
# 0.8404126213592233
# 0.8373524262679606
#
# deffrence between accuracy_score and cross val_score 0.003060195091262763
#
# Model: KNeighborsClassifier
# [0.82180421 0.82918689 0.85669498 0.85678163 0.85880449]
# 0.8397384034519957
# 0.844654441466893
#
# ...

# %% [markdown]
# ## the RandomForestClassifier model is best model for oour data¶
# ## its top performing modal with 89.22% accurecy
# ## less deffrence in cross validation score {0.3%}¶

# %% [markdown]
# ### now lets use hyper parameter tuning on our best model¶¶

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=4)
GCV.fit(x_train,y_train)

# %%
GCV.best_params_

# %%
final_model=RandomForestClassifier(max_features='auto', min_samples_leaf= 1,min_samples_split=5,n_estimators= 300)
final_model.fit(x_train,y_train)
predf=final_model.predict(x_test)
accuracy=accuracy_score(y_test,predf)
accuracy*100
# Out:
# 89.77885652642934

# %% [markdown]
# ### lets chek the ROC curve¶

# %%
from sklearn import metrics

# %%
fpr,tpr,thresholds=metrics.roc_curve(y_test,predf)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=final_model)
display.plot()

# %%
import joblib

# %%
joblib.dump(final_model,"Census Income")
# Out:
# ['Census Income']
