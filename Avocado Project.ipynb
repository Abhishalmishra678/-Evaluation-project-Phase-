# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
DATA=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv')

# %%
df=DATA

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# 5         5.0  22-11-2015          1.26      55979.78  1184.27   48067.99
# 6         6.0  15-11-2015          0.99      83453.76  1368.92   73672.72
# 7         7.0  08-11-2015          0.98     109428.33   703.75  101815.36
# 8         8.0  01-11-2015          1.02      99811.42  1022.15   87315.57
# 9         9.0  25-10-2015          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16458         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16459         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16460         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16461         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16462         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16463         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 16458         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# ...

# %%
df.shape       # printing shaoe of data set
# Out:
# (16468, 14)

# %%
df.columns.to_frame()     # printing columns name in form of data frame
# Out:
#                          0
# Unnamed: 0      Unnamed: 0
# Date                  Date
# AveragePrice  AveragePrice
# Total Volume  Total Volume
# 4046                  4046
# 4225                  4225
# 4770                  4770
# Total Bags      Total Bags
# Small Bags      Small Bags
# Large Bags      Large Bags
# XLarge Bags    XLarge Bags
# type                  type
# year                  year
# region              region

# %%
df.info()           # some basic information about columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# #                          note
# ### by obsarving the data set we can see we have total 14 columns
# ### in wich columns name "Unnamed" is not recognize and seem not part of the data.
# ### in the given problem we have two dependent variable[lebal] 1).AveragePrice  2)region
# ### by loking at bottom of the data set very huge amount of nall value found in every column.
# ### and also the data type of column 'date' is not correct .

# %%
df['Date'] = pd.to_datetime(df['Date'])   # fixing problem of wrong data type in column 'date'.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   datetime64[ns]
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: datetime64[ns](1), float64(11), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ## as seen in above info method the problem has be resolved.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
sns.heatmap(df.isnull(),color='red')
# Out:
# <Axes: >

# %% [markdown]
# ## as seen in the heatmap we found equal amount of null values in all column and same position.
# ## we are going to drop all those rows.

# %%
df.dropna(inplace=True)             # droping all null values rows.

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)      # droping columns wich is anrecognize .

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.shape
# Out:
# (1517, 13)

# %%
df.tail(10)
# Out:
#            Date  AveragePrice  Total Volume      4046      4225      4770  \
# 1507 2016-11-20          1.57     135608.11  44044.69  28907.47  13913.04
# 1508 2016-11-13          1.64     144089.12  49399.39  26597.39  22714.68
# 1509 2016-06-11          1.57     142095.92  36840.74  27501.34  25305.86
# 1510 2016-10-30          1.58     142955.49  39376.44  29382.30  26881.22
# 1511 2016-10-23          1.52     167741.27  54981.90  39749.81  20290.31
# 1512 2016-10-16          1.39     190846.01  57529.11  56366.66  17531.78
# 1513 2016-09-10          1.51     178235.75  43325.87  52189.61  19419.57
# 1514 2016-02-10          1.48     178410.82  46364.75  52893.38  16736.92
# 1515 2016-09-25          1.47     189131.52  54110.79  53593.58  17495.42
# 1516 2016-09-18          1.43     182978.30  43116.41  54193.42  16563.91
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 1507    48742.91    42721.62     6021.29         0.00  conventional  2016.0
# ...

# %% [markdown]
# ### now we have 13 columns and 1517 rows in data set

# %%
df.nunique()                   # cheking for sum of unique values .
# Out:
# Date             104
# AveragePrice     113
# Total Volume    1517
# 4046            1517
# 4225            1517
# 4770            1516
# Total Bags      1517
# Small Bags      1517
# Large Bags      1377
# XLarge Bags      711
# type               1
# year               2
# region            51
# dtype: int64

# %% [markdown]
# ### the 'type' column has only one unique value as in problem statement
# ### as par me we can drop thet column it has nothing to contribute in prediction.

# %%
df.nunique().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.drop('type',axis=1,inplace=True)

# %% [markdown]
# ### the above bar plot represent count of unique values .

# %%
for i in df.columns:
    print(df[i].value_counts())          # printing all unique values as par there columns.
    print('/n'*45)
# Out:
# 2015-12-04    34
# 2015-05-04    34
# 2015-04-19    33
# 2015-10-05    32
# 2015-03-22    32
#               ..
# 2016-10-07     3
# 2016-03-07     3
# 2016-06-26     3
# 2016-06-19     3
# 2016-11-09     2
# Name: Date, Length: 104, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 1.08    46
# 0.99    44
# 1.03    44
# 1.10    43
# 1.09    43
#         ..
# 0.51     1
# 0.52     1
# 0.54     1
# 1.42     1
# 1.58     1
# Name: AveragePrice, Length: 113, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 64236.62      1
# 332918.70     1
# 4565207.85    1
# 4831664.77    1
# 309024.22     1
#              ..
# 141875.20     1
# 92599.79      1
# 98097.37      1
# 162559.72     1
# 182978.30     1
# Name: Total Volume, Length: 1517, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 1036.74       1
# ...

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %% [markdown]
# #                                          note
# ### the describe method give us the statstical information about numerical columns
# ### 1) columns [AveragePrice,Total Volume,4046,4770,Total Bags,Small Bags,Large Bags	,] has high median(50%) as compaire to there mean value that mens those columns are skewed to the right
# ### 2) and column [4225,XLarge Bags	] has low median(50%) as compair to there mean value that ment
# ### they are skewed to the left .
# ### 3) the only column who has very high deffrence in 75% and mas value is [XLarge Bags	].

# %%
df.skew()                    #cheking for the skewness score
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %% [markdown]
# ### as seen in the skew method all columns skew score is very high acept averageprice.

# %% [markdown]
# # EDA

# %% [markdown]
#  ### univaret anlysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='AveragePrice',data=df)
# Out:
# <Axes: xlabel='AveragePrice', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Total Volume',data=df)
# Out:
# <Axes: xlabel='Total Volume', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='4046',data=df)
# Out:
# <Axes: xlabel='4046', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='4225',data=df)
# Out:
# <Axes: xlabel='4225', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='4770',data=df)
# Out:
# <Axes: xlabel='4770', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Total Bags',data=df)
# Out:
# <Axes: xlabel='Total Bags', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Small Bags',data=df)
# Out:
# <Axes: xlabel='Small Bags', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Large Bags',data=df)
# Out:
# <Axes: xlabel='Large Bags', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='XLarge Bags',data=df)
# Out:
# <Axes: xlabel='XLarge Bags', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='year',data=df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='region',data=df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# ### biverate anlysis

# %%
sns.scatterplot(x='Total Volume',y='AveragePrice',hue='region',data=df,palette='bright')
# Out:
# <Axes: xlabel='Total Volume', ylabel='AveragePrice'>

# %%
sns.lmplot(x='4046',y='AveragePrice',hue='region',data=df,palette='bright')

# %%
sns.lmplot(x='4225',y='AveragePrice',hue='region',data=df,palette='bright')

# %%
sns.lmplot(x='4770',y='AveragePrice',hue='region',data=df,palette='bright')

# %%
sns.lmplot(x='AveragePrice',y='year',hue='region',data=df,palette='bright')

# %%
sns.scatterplot(x='AveragePrice',y='Small Bags',hue='region',data=df,palette='bright')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Small Bags'>

# %%
sns.scatterplot(x='AveragePrice',y='Large Bags',hue='region',data=df,palette='bright')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Large Bags'>

# %%
sns.scatterplot(x='AveragePrice',y='XLarge Bags',hue='region',data=df,palette='bright')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='XLarge Bags'>

# %%
sns.pairplot(df)

# %% [markdown]
# ###  lets chek the outliersin box plot

# %%
plt.figure(figsize=(20,25))
value=1
for col in df:
    if value <=10:
        if df.dtypes[col] == 'int64'or df.dtypes[col] == 'float64':
            g=plt.subplot(5,2,value)
            sns.boxplot(df[col],palette="Set2_r")
            plt.xlabel(col,fontsize=14)
            plt.yticks(rotation=0,fontsize=14)
    value+=1
plt.tight_layout()

# %% [markdown]
# ### as seen in above box plot so many outlirs are present in columns.

# %% [markdown]
# ## lets se outlies in detail

# %%
from scipy import stats
from scipy.stats import zscore

# %%
out_columns=df[['AveragePrice','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags',]]
z_scor=np.abs(zscore(out_columns))

# %%
np.where(z_scor>3)
# Out:
# (array([ 412,  760, 1059, 1182, 1182, 1182, 1182, 1182, 1182, 1182, 1183,
#         1183, 1183, 1183, 1183, 1183, 1183, 1184, 1184, 1184, 1184, 1184,
#         1184, 1184, 1185, 1185, 1185, 1185, 1185, 1185, 1185, 1186, 1186,
#         1186, 1186, 1186, 1186, 1186, 1187, 1187, 1187, 1187, 1187, 1187,
#         1187, 1188, 1188, 1188, 1188, 1188, 1188, 1188, 1189, 1189, 1189,
#         1189, 1189, 1189, 1189, 1190, 1190, 1190, 1190, 1190, 1190, 1190,
#         1191, 1191, 1191, 1191, 1191, 1191, 1191, 1192, 1192, 1192, 1192,
#         1192, 1192, 1192, 1193, 1193, 1193, 1193, 1193, 1193, 1193, 1194,
#         1194, 1194, 1194, 1194, 1194, 1194, 1195, 1195, 1195, 1195, 1195,
#         1195, 1195, 1196, 1196, 1196, 1196, 1196, 1196, 1196, 1197, 1197,
#         1197, 1197, 1197, 1197, 1197, 1198, 1198, 1198, 1198, 1198, 1198,
#         1198, 1199, 1199, 1199, 1199, 1199, 1199, 1199, 1200, 1200, 1200,
#         1200, 1200, 1200, 1200, 1201, 1201, 1201, 1201, 1201, 1201, 1201,
# ...

# %%
df1=df[(z_scor<3).all(axis=1)]        # removing outliars

# %%
print('before',df.shape)
print('after',df1.shape)
# Out:
# before (1517, 12)
# after (1471, 12)

# %% [markdown]
# ## we got 3% of data loss.

# %%
plt.figure(figsize=(20,30))
plot_v=1
for col in df1:
    if plot_v <=10:
        if df.dtypes[col] == 'int64'or df.dtypes[col] == 'float64':
            p=plt.subplot(5,2,plot_v)
            sns.distplot(df1[col],color='red')
            plt.xlabel(col,fontsize=10)
            plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout() 
df.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
df1['Total Volume']=np.cbrt(df1['Total Volume'])
df1['4046']=np.cbrt(df1['4046'])
df1['4225']=np.cbrt(df1['4225'])
df1['4770']=np.cbrt(df1['4770'])
df1['Total Bags']=np.cbrt(df1['Total Bags']) # removing skewness with cube root(cbrt) methode
df1['Small Bags']=np.cbrt(df1['Small Bags'])
df1['Large Bags']=np.cbrt(df1['Large Bags'])
df1['XLarge Bags']=np.cbrt(df1['XLarge Bags'])

# %%
df1.skew()
# Out:
# AveragePrice   -0.178772
# Total Volume    1.283854
# 4046            1.149067
# 4225            0.923598
# 4770            1.084690
# Total Bags      1.595889
# Small Bags      1.623749
# Large Bags      0.856780
# XLarge Bags     2.162343
# year            1.825081
# dtype: float64

# %% [markdown]
# ## now its looking better.

# %% [markdown]
# # let chek if data has any multicolinearty issue.

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# ...

# %%
cor=df1.corr()
plt.figure(figsize=(15,15))
sns.heatmap(cor,linewidths=0.1,fmt='.1g',linecolor='black',annot= True,cmap='Blues_r') # ploting heatmap of corr method.
# Out:
# <Axes: >

# %% [markdown]
# # obsarvation
# ### Total volume, 4046, 4225, 4770, Total bags, small bags and large bags all have high correlation amongst them as seen in the heatmap.
# ### Most of the columns have negative correlation with Average Price.

# %% [markdown]
# ### now lets encode the object type columns.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()                                  # encoding withe the lebal encoder.
df1['region'] = label_encoder.fit_transform(df1['region'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1471 entries, 0 to 1516
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1471 non-null   datetime64[ns]
#  1   AveragePrice  1471 non-null   float64
#  2   Total Volume  1471 non-null   float64
#  3   4046          1471 non-null   float64
#  4   4225          1471 non-null   float64
#  5   4770          1471 non-null   float64
#  6   Total Bags    1471 non-null   float64
#  7   Small Bags    1471 non-null   float64
#  8   Large Bags    1471 non-null   float64
#  9   XLarge Bags   1471 non-null   float64
#  10  year          1471 non-null   float64
#  11  region        1471 non-null   int32
# dtypes: datetime64[ns](1), float64(10), int32(1)
# memory usage: 143.7 KB

# %%
df1.set_index('Date', inplace=True)         # setting date column as index

# %%
DFXR=df1.drop('AveragePrice', axis=1)
DFYR=df1['AveragePrice']
DFXC=df1.drop('region', axis=1)
DFYC=df1['region']

# %%
DFXR.drop('Small Bags',axis=1,inplace=True) # coz perfectly correlated with total bags column.

# %%
DFXR.head(10)
# Out:
#             Total Volume       4046       4225      4770  Total Bags  \
# Date
# 2015-12-27     40.049235  10.120997  37.903460  3.638275   20.564634
# 2015-12-20     38.001150   8.768933  35.473513  3.878204   21.183249
# 2015-12-13     49.079175   9.262632  47.790416  5.072283   20.120399
# 2015-06-12     42.906983  10.421946  41.597133  4.171309   17.978534
# 2015-11-29     37.093893   9.800999  35.260208  4.231732   18.355039
# 2015-11-22     38.254018  10.579949  36.359563  3.519887   18.836933
# 2015-11-15     43.700054  11.103486  41.921380  4.534873   20.262263
# 2015-08-11     47.831051   8.894867  46.695077  4.308869   18.972462
# 2015-01-11     46.386693  10.073295  44.363987  4.402684   22.498509
# 2015-10-25     42.047331   9.444365  40.157182  4.834588   20.508559
#
#             Large Bags  XLarge Bags    year  region
# Date
# 2015-12-27    4.534711          0.0  2015.0       0
# 2015-12-20    4.602425          0.0  2015.0       0
# ...

# %%
DFYR.tail(10)
# Out:
# Date
# 2016-11-20    1.57
# 2016-11-13    1.64
# 2016-06-11    1.57
# 2016-10-30    1.58
# 2016-10-23    1.52
# 2016-10-16    1.39
# 2016-09-10    1.51
# 2016-02-10    1.48
# 2016-09-25    1.47
# 2016-09-18    1.43
# Name: AveragePrice, dtype: float64

# %%
DFXC.head(10)
# Out:
#             AveragePrice  Total Volume       4046       4225      4770  \
# Date
# 2015-12-27          1.33     40.049235  10.120997  37.903460  3.638275
# 2015-12-20          1.35     38.001150   8.768933  35.473513  3.878204
# 2015-12-13          0.93     49.079175   9.262632  47.790416  5.072283
# 2015-06-12          1.08     42.906983  10.421946  41.597133  4.171309
# 2015-11-29          1.28     37.093893   9.800999  35.260208  4.231732
# 2015-11-22          1.26     38.254018  10.579949  36.359563  3.519887
# 2015-11-15          0.99     43.700054  11.103486  41.921380  4.534873
# 2015-08-11          0.98     47.831051   8.894867  46.695077  4.308869
# 2015-01-11          1.02     46.386693  10.073295  44.363987  4.402684
# 2015-10-25          1.07     42.047331   9.444365  40.157182  4.834588
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags    year
# Date
# 2015-12-27   20.564634   20.490870    4.534711          0.0  2015.0
# ...

# %%
DFYC.tail(10)
# Out:
# Date
# 2016-11-20    7
# 2016-11-13    7
# 2016-06-11    7
# 2016-10-30    7
# 2016-10-23    7
# 2016-10-16    7
# 2016-09-10    7
# 2016-02-10    7
# 2016-09-25    7
# 2016-09-18    7
# Name: region, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
scal=StandardScaler()

# %%
DFXR=pd.DataFrame(scal.fit_transform(DFXR),columns=DFXR.columns)

# %%
DFXC=pd.DataFrame(scal.fit_transform(DFXC),columns=DFXC.columns)

# %%
DFXR.describe()
# Out:
#        Total Volume          4046          4225          4770    Total Bags  \
# count  1.471000e+03  1.471000e+03  1.471000e+03  1.471000e+03  1.471000e+03
# mean   9.660676e-17  2.318562e-16 -2.415169e-18 -4.830338e-18  2.801596e-16
# std    1.000340e+00  1.000340e+00  1.000340e+00  1.000340e+00  1.000340e+00
# min   -1.210211e+00 -1.216618e+00 -1.469953e+00 -1.376404e+00 -1.445144e+00
# 25%   -7.411022e-01 -6.888798e-01 -7.562841e-01 -7.932287e-01 -6.484378e-01
# 50%   -2.382155e-01 -2.702704e-01 -3.413021e-01 -1.952005e-01 -2.470298e-01
# 75%    3.729850e-01  3.971374e-01  5.828865e-01  4.218160e-01  2.270285e-01
# max    3.086067e+00  3.177903e+00  2.958518e+00  3.350607e+00  3.874870e+00
#
#          Large Bags  XLarge Bags          year       region
# count  1.471000e+03  1471.000000  1.471000e+03  1471.000000
# mean   1.932135e-17     0.000000 -2.911728e-13     0.000000
# std    1.000340e+00     1.000340  1.000340e+00     1.000340
# ...

# %%
DFXC.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  1.471000e+03  1.471000e+03  1.471000e+03  1.471000e+03  1.471000e+03
# mean  -9.467463e-16  9.660676e-17  2.318562e-16 -2.415169e-18 -4.830338e-18
# std    1.000340e+00  1.000340e+00  1.000340e+00  1.000340e+00  1.000340e+00
# min   -3.030148e+00 -1.210211e+00 -1.216618e+00 -1.469953e+00 -1.376404e+00
# 25%   -5.215523e-01 -7.411022e-01 -6.888798e-01 -7.562841e-01 -7.932287e-01
# 50%    1.219157e-02 -2.382155e-01 -2.702704e-01 -3.413021e-01 -1.952005e-01
# 75%    5.993098e-01  3.729850e-01  3.971374e-01  5.828865e-01  4.218160e-01
# max    3.001157e+00  3.086067e+00  3.177903e+00  2.958518e+00  3.350607e+00
#
#          Total Bags    Small Bags    Large Bags  XLarge Bags          year
# count  1.471000e+03  1.471000e+03  1.471000e+03  1471.000000  1.471000e+03
# mean   2.801596e-16 -9.660676e-17  1.932135e-17     0.000000 -2.911728e-13
# ...

# %% [markdown]
# # regrresion

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import ExtraTreesRegressor

# %%
MAXXACU=0
MAXRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(DFXR,DFYR,test_size=0.25,random_state=i)
    ler=LinearRegression()
    ler.fit(x_train,y_train)
    pred=ler.predict(x_test)
    acc=r2_score(y_test,pred)   # finding best rendom state for data set.
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX R2_score is-',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX R2_score is- 0.45916616586902603 BEST rendom state is 40

# %% [markdown]
# ### now we get the best rendom state for aur data

# %%
x_train,x_test,y_train,y_test=train_test_split(DFXR,DFYR,test_size=0.25,random_state=MAXRS)

# %% [markdown]
# ### defing the all evaluation method to one

# %%
def evaluation(model, prediction, x_train, y_train, x_test, y_test):
    print('mean absolute error : %.2f' % mean_absolute_error(y_test,prediction)) 
    print('mean_squared error: %.2f' % mean_squared_error(y_test, prediction, squared=False)) 
    print('R2 score : %.2f' % r2_score(y_test, prediction)) 
    print('Train Accuracy :', model.score(x_train, y_train)) 
    print('Test Accuracy :', model.score(x_test, y_test))

# %% [markdown]
# ### making all modal as a singal modal

# %%
models = {
    'LinearRegression' : LinearRegression(),
    'DecisionTree'     : DecisionTreeRegressor(),
    'RandomForest'     : RandomForestRegressor(),
    'Ridge'            : Ridge(),
    'Lasso'            : Lasso(),
    'SVR'              : SVR(),
    'ElasticNet'       : ElasticNet(),
    'KNeighborsRegressor':KNeighborsRegressor(),
    'GradientBoostingRegressor':GradientBoostingRegressor(),
    'XGBRegressor'      :  XGBRegressor(),
    'ExtraTreesRegressor':ExtraTreesRegressor()
}

# %% [markdown]
# ### Nnow lets train all modal at once,

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    prediction1 = model.predict(x_test)
    print('Model: {}'.format(model_name))
    print(evaluation(model, prediction1, x_train, y_train, x_test, y_test), 
          '\n')
# Out:
# Model: LinearRegression
# mean absolute error : 0.10
# mean_squared error: 0.13
# R2 score : 0.46
# Train Accuracy : 0.34399323252931635
# Test Accuracy : 0.45916616586902603
# None
#
# Model: DecisionTree
# mean absolute error : 0.07
# mean_squared error: 0.10
# R2 score : 0.70
# Train Accuracy : 1.0
# Test Accuracy : 0.6973314955058172
# None
#
# Model: RandomForest
# mean absolute error : 0.05
# mean_squared error: 0.07
# R2 score : 0.84
# Train Accuracy : 0.9748577742387007
# Test Accuracy : 0.8442190615275353
# None
#
# Model: Ridge
# mean absolute error : 0.10
# mean_squared error: 0.13
# R2 score : 0.46
# Train Accuracy : 0.3437236614096174
# Test Accuracy : 0.458179665990873
# None
#
# Model: Lasso
# mean absolute error : 0.13
# mean_squared error: 0.18
# R2 score : -0.01
# Train Accuracy : 0.0
# Test Accuracy : -0.009225209532371714
# None
#
# Model: SVR
# mean absolute error : 0.07
# mean_squared error: 0.09
# R2 score : 0.76
# Train Accuracy : 0.7700845292048165
# ...

# %% [markdown]
# ## heare are modal  R2 scores¶
# #### LinearRegression                   :0.46%
# #### DecisionTree                       :0.70%
# #### RandomForest                       :0.84%
# #### Ridge                              :0.46%
# #### Lasso                              :-0.01%
# #### SVR                                :0.76%
# #### ElasticNet                         :0.01%
# #### KNeighborsRegressor                :0.82%
# #### GradientBoostingRegressor          :0.75%
# #### XGBRegressor                       :0.82%
# #### ExtraTreesRegressor             :88%
# ## till now ExtraTreesRegressor is the leading with score of 88% .

# %% [markdown]
# ### now lets cross validate all model with cross validation method.

# %%
for model_name, model in models.items():
    score=cross_val_score(model,DFXR,DFYR,cv=5,scoring='r2')
    print('Model: {}'.format(model_name))
    print(score)
    print(model.score(x_test, y_test))
    print(score.mean())
    print('deffrence between r2_score and cross val_score',(model.score(x_test, y_test)) -(score.mean()))
    print('                                                                                   ')
# Out:
# Model: LinearRegression
# [-1.57322492  0.11517578  0.4040983   0.107776    0.1235821 ]
# 0.45916616586902603
# -0.1645185494312989
# deffrence between r2_score and cross val_score 0.6236847153003249
#
# Model: DecisionTree
# [-1.71137833 -0.10096784  0.25196223 -0.07344735  0.02326409]
# 0.6973314955058172
# -0.32211344007286485
# deffrence between r2_score and cross val_score 1.019444935578682
#
# Model: RandomForest
# [-0.81412205 -0.01092109  0.4503509   0.30953426  0.25676632]
# 0.8442190615275353
# 0.03832166752001802
# deffrence between r2_score and cross val_score 0.8058973940075174
#
# Model: Ridge
# [-1.54917375  0.13778499  0.40004733  0.1012147   0.12719042]
# 0.458179665990873
# -0.1565872632760233
# deffrence between r2_score and cross val_score 0.6147669292668962
#
# Model: Lasso
# [-0.21313472 -0.06173094 -0.01039905 -0.01525265 -0.01286792]
# -0.009225209532371714
# -0.06267705638452443
# deffrence between r2_score and cross val_score 0.05345184685215272
#
# ...

# %% [markdown]
# # as par my obsarvetin ExtraTreesRegressor is best performing node
# ### why!
# #### geving highest r2 score of 88 %
# #### geving less mean absolute error and mean_squared error
# #### geving less defrence in cross validatin score

# %% [markdown]
# ## now lets do hyper parameter tunig on ExtraTreesRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'n_estimators': [100, 300, 400],
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
    'bootstrap': [True, False]
}

# %%
gcsv=GridSearchCV(ExtraTreesRegressor (),parameters,cv=5)
gcsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [None, 5, 10, 15],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 300, 400]})

# %%
gcsv.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 400}

# %%
final_model=ExtraTreesRegressor(bootstrap= False,max_depth= None ,max_features= 'auto',min_samples_leaf=1,min_samples_split= 2,n_estimators=400)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
print('final modal score test ',model.score(x_test, y_test))
print('r2_score',r2_score(y_test,pred))
print('mean absolute error',mean_absolute_error(y_test,pred))
print('mean squared error',mean_squared_error(y_test,pred))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# final modal score test  0.8834964939065081
# r2_score 0.8889728701873756
# mean absolute error 0.04447160326086954
# mean squared error 0.0035504515692934752
# root mean squared error 0.05958566580389511

# %% [markdown]
# # final_modal r2_score is 88.34 %¶

# %% [markdown]
# ## classification

# %% [markdown]
# ### lets import all the libreries for models

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

# %%
DFXC
# Out:
#       AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         1.346551     -1.054002 -1.151583 -0.644523 -1.152274   -1.191794
# 1         1.453300     -1.105524 -1.188864 -0.722339 -1.137493   -1.164098
# 2        -0.788424     -0.826840 -1.175251 -0.327908 -1.063934   -1.211683
# 3         0.012192     -0.982111 -1.143285 -0.526239 -1.119437   -1.307574
# 4         1.079679     -1.128348 -1.160407 -0.729170 -1.115715   -1.290718
# ...            ...           ...       ...       ...       ...         ...
# 1466      1.666797     -0.613136 -0.366216 -0.630482  0.223941   -0.365463
# 1467      2.307290     -0.645766 -0.462212 -0.661593  0.279435   -0.328215
# 1468      2.147167     -0.645302 -0.440079 -0.656238  0.199380   -0.336569
# 1469      2.093793     -0.617486 -0.387730 -0.650957  0.222834   -0.322306
# 1470      1.880295     -0.633319 -0.463775 -0.646469  0.193932   -0.275270
#
#       Small Bags  Large Bags  XLarge Bags      year
# ...

# %%
DFYC
# Out:
# Date
# 2015-12-27    0
# 2015-12-20    0
# 2015-12-13    0
# 2015-06-12    0
# 2015-11-29    0
#              ..
# 2016-10-16    7
# 2016-09-10    7
# 2016-02-10    7
# 2016-09-25    7
# 2016-09-18    7
# Name: region, Length: 1471, dtype: int32

# %%
MAXXACU=0
MAXRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(DFXC,DFYC,test_size=0.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX accuracy is',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX accuracy is 0.918552036199095 BEST rendom state is 24

# %%
x_train,x_test,y_train,y_test=train_test_split(DFXC,DFYC,test_size=0.30,random_state=MAXRS)

# %% [markdown]
# ### now we have the best randoom state value "167"
# ### we will use this value to build models¶

# %%
def evaluation(model, prediction, x_train, y_train, x_test, y_test):
    print(accuracy_score(y_test,prediction))
    print(confusion_matrix(y_test,prediction))
    print(classification_report(y_test,prediction))   # defing the all evaluation method to one

# %% [markdown]
# ### making all modal as a singal modal

# %%
models = {
    'LogisticRegression'         : LogisticRegression(),
    'DecisionTreeClassifier'     : DecisionTreeClassifier(),
    'RandomForestClassifier'     : RandomForestClassifier(),
    'SVC'                        : SVC(),
    'KNeighborsClassifier'       : KNeighborsClassifier(),
    'GaussianNB'                 : GaussianNB(),
    'GradientBoostingClassifier' : GradientBoostingClassifier(),
    'MLPClassifier'              :MLPClassifier()
}

# %% [markdown]
# ### now lets train all modal at once,

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    prediction1 = model.predict(x_test)
    print('Model: {}'.format(model_name))
    print(evaluation(model, prediction1, x_train, y_train, x_test, y_test), 
          '\n')
# Out:
# Model: LogisticRegression
# 0.8733031674208145
# [[18  0  0 ...  0  0  0]
#  [ 0 14  0 ...  0  0  0]
#  [ 0  0 19 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  8  0  0]
#  [ 0  0  0 ...  0  5  0]
#  [ 0  0  0 ...  0  0  6]]
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        18
#            1       0.88      1.00      0.93        14
#            2       0.90      0.90      0.90        21
#            3       0.94      0.94      0.94        18
#            4       0.87      0.93      0.90        14
#            5       1.00      0.92      0.96        12
#            6       1.00      1.00      1.00        27
#            7       0.69      0.90      0.78        10
#            8       1.00      1.00      1.00         5
#            9       0.75      0.92      0.83        13
#           10       1.00      0.17      0.29         6
#           11       0.89      1.00      0.94         8
# ...

# %% [markdown]
# ## ALL MODEL SCORE:
# ## 'LogisticRegression'         :0.8733031674208145
# ##    'DecisionTreeClassifier'     :0.916289592760181
# ##   'RandomForestClassifier'     : 0.9841628959276018
# ##    'SVC'                        :0.8552036199095022
# ##    'KNeighborsClassifier'       : 0.920814479638009
# ##    'GaussianNB'                 : 0.8687782805429864
# ##    'GradientBoostingClassifier' : 0.9095022624434389
# ##   'MLPClassifier'              :0.9547511312217195

# %% [markdown]
# ## lets cross validate all models with cross_val_score method¶

# %%
for model_name, model in models.items():
    score=cross_val_score(model,DFXC,DFYC,cv=5,)
    print('Model: {}'.format(model_name))
    print(score)
    print(model.score(x_test, y_test))
    print(score.mean())
    print("                                                                                  ")
    print('deffrence between accuracy_score and cross val_score',(model.score(x_test, y_test)) -(score.mean()))
    print("                                                                                  ")
# Out:
# Model: LogisticRegression
# [0.75932203 0.84693878 0.93537415 0.84693878 0.83333333]
# 0.8733031674208145
# 0.8443814135823822
#
# deffrence between accuracy_score and cross val_score 0.028921753838432318
#
# Model: DecisionTreeClassifier
# [0.73559322 0.87414966 0.84353741 0.87755102 0.78571429]
# 0.916289592760181
# 0.8233091202582727
#
# deffrence between accuracy_score and cross val_score 0.09298047250190822
#
# Model: RandomForestClassifier
# [0.84745763 0.94897959 0.95578231 0.97278912 0.91156463]
# 0.9841628959276018
# 0.9273146546754294
#
# deffrence between accuracy_score and cross val_score 0.05684824125217236
#
# Model: SVC
# [0.73220339 0.81972789 0.91496599 0.88435374 0.80952381]
# 0.8552036199095022
# 0.8321549636803874
#
# deffrence between accuracy_score and cross val_score 0.023048656229114783
#
# Model: KNeighborsClassifier
# [0.83728814 0.91496599 0.92857143 0.92857143 0.82312925]
# 0.920814479638009
# 0.8865052461662632
#
# ...

# %% [markdown]
# ## after obsarving all model score , confusion_matrix and cross validation score.
# ## RandomForestClassifier is our best model

# %% [markdown]
# ### now lets use hyper parameter tuning on our best model

# %%
parameters = {
    'n_estimators': [100, 300, 400],
    'max_depth': [ 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
    'bootstrap': [True, False],
    'class_weight': ['balanced', 'balanced_subsample']
}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)

# %%
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'class_weight': 'balanced',
#  'max_depth': 15,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %%
final_modelC=RandomForestClassifier(bootstrap=True,class_weight= 'balanced',max_depth= 15, max_features='sqrt',min_samples_leaf= 1,min_samples_split=5,n_estimators= 300)
final_modelC.fit(x_train,y_train)
predC=final_modelC.predict(x_test)
accuracy=accuracy_score(y_test,predf)
accuracy*100
# Out:
# 98.19004524886877

# %% [markdown]
# ## the final model scpre is 98.19 %

# %% [markdown]
# ### lets save the modal( region  classification)

# %%
import joblib

# %%
joblib.dump(final_model,"Avocado Project region")

# %% [markdown]
# ### lets save the modal ( AveragePrice regrresion )

# %%
joblib.dump(final_model,"Avocado Project AveragePrice")
# Out:
# ['Avocado Project AveragePrice']
